# %%
import math

def ent(num):
    return -num * math.log2(num) - (1 - num) * math.log2(1 - num)

# %%
a = ent(1/2) - 3/8 * ent(1/3) - 5/8 * ent(2/5)

b = ent(1/2) - ent(4/5) * 5/8

c = ent(1/2) - ent(3/4) * 2 * 1/2

print(a)
print(b)
print(c)
# Out:
# 0.04879494069539858
# 0.5487949406953986
# 0.18872187554086717

# %%
aa = ent(4/5) - ent(1/3) * 3/5

cc = ent(4/5) - ent(1/2) * 2/5

print(aa)

print(cc)
# Out:
# 0.17095059445466854
# 0.3219280948873623

# %%
aaa = ent(1/2) - 0
print(aaa)
# Out:
# 1.0

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
import numpy as np
import matplotlib.pyplot as plt

data = np.array([
    [True, True, False, False],
    [False, True, True, False],
    [False, True, False, False],
    [False, False, True, True],
    [True, False, True, True],
    [True, False, False, True],
    [False, False, True, True],
    [False, False, False, False]]
)
train = data[:, 0: 3]
target = data[:, 3:]

clf = DecisionTreeClassifier()

clf.fit(train, target)

plot_tree(clf, filled=True)
# Out:
# [Text(0.6666666666666666, 0.875, 'x[1] <= 0.5\ngini = 0.5\nsamples = 8\nvalue = [4, 4]'),
#  Text(0.5, 0.625, 'x[2] <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.3333333333333333, 0.375, 'x[0] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.16666666666666666, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6666666666666666, 0.375, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.8333333333333334, 0.625, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]')]
